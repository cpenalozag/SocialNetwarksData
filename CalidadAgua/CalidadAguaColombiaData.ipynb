# %%
# Imports
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import operator
import requests
import difflib
import json
import math
import time

#%matplotlib inline

# %%
# Import data
url_data = 'https://raw.githubusercontent.com/cpenalozag/SocialNetworksData/master/CalidadAgua/Calidad_Agua_SIVICAP.csv'
data = pd.read_csv(url_data)
        
nodes = {}
 
# Fill node dictionary
for index, row in data.iterrows():
    nodes[row['MUNICIPO']]={'riesgo': row['NIVEL DE RIESGO PROMEDIO'], 'departamento': row['DEPARTAMENTO']}

# Import population data
url_population = 'https://raw.githubusercontent.com/cpenalozag/SocialNetworksData/master/CalidadAgua/Poblacion_Municipios.csv'
population = pd.read_csv(url_population, sep=';')

def similar(landstring, country):
  l = difflib.get_close_matches(landstring, country, 1)
  if not l: return []
  return l[0]

population.head()
for index, row in population.iterrows():
  name = similar(row['MPIO'], nodes)
  if not name: continue
  if name in nodes:
    nodes[name]['poblacion']=float(row['2015'])

# %%
# Get coordinates
def coords(query):
  url = "https://us1.locationiq.com/v1/search.php"

  data = {
      'key': '878fbe47c15737',
      'q': query,
      'format': 'json'
  }
  
  response = requests.get(url, params=data)
  
  d = json.loads(response.text)
  
  return (d[0]['lat'], d[0]['lon'])

for n in nodes:
  
  q = '%s, %s' % (n,nodes[n]['departamento'])
  lat_lon = coords(q)
  nodes[n]['lat']=lat_lon[0]
  nodes[n]['lon']=lat_lon[1]
  time.sleep(1) # rate limit: 1 req/second
nodes
# Out:
# {'Abejorral': {'departamento': 'Antioquia',
#   'lat': '5.7914299',
#   'lon': '-75.4270381',
#   'poblacion': 19290.0,
#   'riesgo': 'SIN RIESGO'},
#  'Abrego': {'departamento': 'Norte de Santander',
#   'lat': '8.1420669',
#   'lon': '-73.1196354',
#   'poblacion': 37997.0,
#   'riesgo': 'MEDIO'},
#  'Abriaquí': {'departamento': 'Antioquia',
#   'lat': '6.6284892',
#   'lon': '-76.083530093352',
#   'poblacion': 2128.0,
#   'riesgo': 'SIN RIESGO'},
#  'Acacías': {'departamento': 'Meta',
#   'lat': '3.9861122',
#   'lon': '-73.7583005',
#   'poblacion': 68888.0,
#   'riesgo': 'MEDIO'},
#  'Acevedo': {'departamento': 'Huila',
#   'lat': '1.8070452',
#   'lon': '-75.888501',
#   'poblacion': 32897.0,
#   'riesgo': 'ALTO'},
#  'Achí': {'departamento': 'Bolívar',
#   'lat': '8.60283045',
#   'lon': '-74.4586880450204',
#   'poblacion': 23051.0,
#   'riesgo': 'MEDIO'},
#  'Agrado': {'departamento': 'Huila',
#   'lat': '2.2580718',
#   'lon': '-75.7712079',
#   'poblacion': 8834.0,
#   'riesgo': 'ALTO'},
#  'Aguachica': {'departamento': 'Cesar',
#   'lat': '8.24811845',
#   'lon': '-73.6214038056006',
#   'poblacion': 92957.0,
#   'riesgo': 'SIN RIESGO'},
#  'Aguada': {'departamento': 'Santander',
#   'lat': '6.1796776',
#   'lon': '-73.5277269812528',
#   'poblacion': 1855.0,
#   'riesgo': 'BAJO'},
#  'Aguadas': {'departamento': 'Caldas',
#   'lat': '5.57913355',
#   'lon': '-75.4153222520219',
#   'poblacion': 10995.0,
#   'riesgo': 'ALTO'},
#  'Aguazul': {'departamento': 'Casanare',
#   'lat': '5.1708408',
#   'lon': '-72.550846',
#   'poblacion': 38515.0,
#   'riesgo': 'SIN RIESGO'},
#  'Agustín Codazzi': {'departamento': 'Cesar',
#   'lat': '10.0374894',
#   'lon': '-73.2387011',
#   'poblacion': 50829.0,
#   'riesgo': 'BAJO'},
#  'Aipe': {'departamento': 'Huila',
#   'lat': '3.2386692',
#   'lon': '-75.2945677922753',
#   'poblacion': 26219.0,
#   'riesgo': 'ALTO'},
#  'Albania': {'departamento': 'Santander',
#   'lat': '5.7587654',
#   'lon': '-73.9151617',
#   'poblacion': 5096.0,
#   'riesgo': 'MEDIO'},
#  'Albán': {'departamento': 'Nariño',
#   'lat': '1.0962968',
#   'lon': '-77.5685988',
#   'poblacion': 22131.0,
#   'riesgo': 'ALTO'},
#  'Alcalá': {'departamento': 'Valle del Cauca',
#   'lat': '4.6748944',
#   'lon': '-75.781669',
#   'poblacion': 21352.0,
#   'riesgo': 'MEDIO'},
#  'Aldana': {'departamento': 'Nariño',
#   'lat': '0.8822547',
#   'lon': '-77.7003164',
#   'poblacion': 6085.0,
#   'riesgo': 'MEDIO'},
#  'Alejandría': {'departamento': 'Antioquia',
#   'lat': '6.3557801',
#   'lon': '-75.0986624938931',
#   'poblacion': 4992.0,
#   'riesgo': 'SIN RIESGO'},
#  'Algarrobo': {'departamento': 'Magdalena',
#   'lat': '10.22268125',
#   'lon': '-74.120518108874',
#   'poblacion': 12576.0,
#   'riesgo': 'MEDIO'},
#  'Algeciras': {'departamento': 'Huila',
#   'lat': '2.5246661',
#   'lon': '-75.316688',
#   'poblacion': 24499.0,
#   'riesgo': 'ALTO'},
#  'Almaguer': {'departamento': 'Cauca',
#   'lat': '1.9142744',
#   'lon': '-76.8548514',
#   'poblacion': 21243.0,
#   'riesgo': 'BAJO'},
#  'Almeida': {'departamento': 'Boyacá',
#   'lat': '4.971164',
#   'lon': '-73.3788228',
#   'poblacion': 1754.0,
#   'riesgo': 'ALTO'},
#  'Altamira': {'departamento': 'Huila',
#   'lat': '2.0644',
#   'lon': '-75.7874126',
#   'poblacion': 4293.0,
#   'riesgo': 'ALTO'},
#  'Altos Del Rosario': {'departamento': 'Bolívar',
#   'lat': '8.7920971',
#   'lon': '-74.1639876',
#   'poblacion': 13669.0,
#   'riesgo': 'ALTO'},
#  'Amagá': {'departamento': 'Antioquia',
#   'lat': '6.0358169',
#   'lon': '-75.7009108125',
#   'poblacion': 29555.0,
#   'riesgo': 'SIN RIESGO'},
#  'Amalfi': {'departamento': 'Antioquia',
#   'lat': '7.0204002',
#   'lon': '-74.9504758358016',
#   'poblacion': 22088.0,
#   'riesgo': 'SIN RIESGO'},
#  'Anapoima': {'departamento': 'Cundinamarca',
#   'lat': '4.5638824',
#   'lon': '-74.5249304448066',
#   'poblacion': 13312.0,
#   'riesgo': 'BAJO'},
#  'Ancuyá': {'departamento': 'Nariño',
#   'lat': '1.2615284',
#   'lon': '-77.5147482',
#   'poblacion': 7083.0,
#   'riesgo': 'ALTO'},
#  'Andalucía': {'departamento': 'Valle del Cauca',
#   'lat': '4.1694199',
#   'lon': '-76.1670623',
#   'poblacion': 17811.0,
#   'riesgo': 'BAJO'},
#  'Andes': {'departamento': 'Antioquia',
#   'lat': '5.62787175',
#   'lon': '-75.9451674495186',
#   'poblacion': 45814.0,
#   'riesgo': 'SIN RIESGO'},
#  'Angelópolis': {'departamento': 'Antioquia',
#   'lat': '6.1311539',
#   'lon': '-75.7207562709234',
#   'poblacion': 8946.0,
#   'riesgo': 'SIN RIESGO'},
#  'Angostura': {'departamento': 'Antioquia',
#   'lat': '6.8695288',
#   'lon': '-75.3454161996697',
#   'poblacion': 11354.0,
#   'riesgo': 'SIN RIESGO'},
#  'Anolaima': {'departamento': 'Cundinamarca',
#   'lat': '4.78698015',
#   'lon': '-74.4659698631782',
#   'poblacion': 12311.0,
#   'riesgo': 'BAJO'},
#  'Anorí': {'departamento': 'Antioquia',
#   'lat': '7.17672705',
#   'lon': '-75.1562645503356',
#   'poblacion': 17086.0,
#   'riesgo': 'SIN RIESGO'},
#  'Anserma': {'departamento': 'Caldas',
#   'lat': '5.1993524',
#   'lon': '-75.7494135932917',
#   'poblacion': 33792.0,
#   'riesgo': 'ALTO'},
#  'Ansermanuevo': {'departamento': 'Valle del Cauca',
#   'lat': '4.79058655',
#   'lon': '-76.0434960469551',
#   'poblacion': 19557.0,
#   'riesgo': 'MEDIO'},
#  'Anza': {'departamento': 'Antioquia',
#   'lat': '6.31509295',
#   'lon': '-75.9178133048554',
#   'poblacion': 7568.0,
#   'riesgo': 'SIN RIESGO'},
#  'Anzoátegui': {'departamento': 'Tolima',
#   'lat': '4.6312166',
#   'lon': '-75.0938748',
#   'poblacion': 18434.0,
#   'riesgo': 'MEDIO'},
#  'Apartadó': {'departamento': 'Antioquia',
#   'lat': '7.9220227',
#   'lon': '-76.530722842286',
#   'poblacion': 178257.0,
#   'riesgo': 'SIN RIESGO'},
#  'Apulo': {'departamento': 'Cundinamarca',
#   'lat': '4.53812835',
#   'lon': '-74.5859576869081',
#   'poblacion': 7812.0,
#   'riesgo': 'MEDIO'},
#  'Apía': {'departamento': 'Risaralda',
#   'lat': '5.1065543',
#   'lon': '-75.9425022',
#   'poblacion': 18976.0,
#   'riesgo': 'MEDIO'},
#  'Aquitania': {'departamento': 'Boyacá',
#   'lat': '5.5175808',
#   'lon': '-72.88315',
#   'poblacion': 15241.0,
#   'riesgo': 'MEDIO'},
#  'Aracataca': {'departamento': 'Magdalena',
#   'lat': '10.5906011',
#   'lon': '-74.1876803',
#   'poblacion': 39473.0,
#   'riesgo': 'ALTO'},
#  'Aranzazu': {'departamento': 'Caldas',
#   'lat': '5.2791449',
#   'lon': '-75.4613816960263',
#   'poblacion': 11422.0,
#   'riesgo': 'ALTO'},
#  'Aratoca': {'departamento': 'Santander',
#   'lat': '6.7343173',
#   'lon': '-73.0173345036149',
#   'poblacion': 8312.0,
#   'riesgo': 'MEDIO'},
#  'Arauca': {'departamento': 'Arauca',
#   'lat': '6.9682918',
#   'lon': '-71.1965589',
#   'poblacion': 88481.0,
#   'riesgo': 'SIN RIESGO'},
#  'Arauquita': {'departamento': 'Arauca',
#   'lat': '7.029595',
#   'lon': '-71.4277997',
#   'poblacion': 41309.0,
#   'riesgo': 'SIN RIESGO'},
#  'Arbeláez': {'departamento': 'Cundinamarca',
#   'lat': '4.23374295',
#   'lon': '-74.4124797369768',
#   'poblacion': 12292.0,
#   'riesgo': 'MEDIO'},
#  'Arboleda': {'departamento': 'Nariño',
#   'lat': '1.3438199',
#   'lon': '-77.539261',
#   'poblacion': 6837.0,
#   'riesgo': 'ALTO'},
#  'Arboledas': {'departamento': 'Norte de Santander',
#   'lat': '7.6707185',
#   'lon': '-72.7237135',
#   'poblacion': 8984.0,
#   'riesgo': 'MEDIO'},
#  'Arboletes': {'departamento': 'Antioquia',
#   'lat': '8.6660255',
#   'lon': '-76.4194838482128',
#   'poblacion': 40147.0,
#   'riesgo': 'SIN RIESGO'},
#  'Arcabuco': {'departamento': 'Boyacá',
#   'lat': '5.75520695',
#   'lon': '-73.451371116591',
#   'poblacion': 22513.0,
#   'riesgo': 'MEDIO'},
#  'Arenal': {'departamento': 'Bolívar',
#   'lat': '-1.5725993',
#   'lon': '-78.9185513',
#   'poblacion': 18876.0,
#   'riesgo': 'ALTO'},
#  'Argelia': {'departamento': 'Valle del Cauca',
#   'lat': '4.7271938',
#   'lon': '-76.1211518',
#   'poblacion': 6440.0,
#   'riesgo': 'ALTO'},
#  'Ariguaní': {'departamento': 'Magdalena',
#   'lat': '9.8005467',
#   'lon': '-74.0599546310224',
#   'poblacion': 32166.0,
#   'riesgo': 'ALTO'},
#  'Arjona': {'departamento': 'Bolívar',
#   'lat': '10.17840655',
#   'lon': '-75.3552890273773',
#   'poblacion': 72514.0,
#   'riesgo': 'BAJO'},
#  'Armenia': {'departamento': 'Quindio',
#   'lat': '4.4925756',
#   'lon': '-75.7394764685402',
#   'poblacion': 296691.0,
#   'riesgo': 'SIN RIESGO'},
#  'Armero': {'departamento': 'Tolima',
#   'lat': '4.9550681',
#   'lon': '-74.9074644',
#   'poblacion': 11960.0,
#   'riesgo': 'SIN RIESGO'},
#  'Arroyohondo': {'departamento': 'Bolívar',
#   'lat': '10.2512203',
#   'lon': '-75.0190389',
#   'poblacion': 9907.0,
#   'riesgo': 'MEDIO'},
#  'Astrea': {'departamento': 'Cesar',
#   'lat': '9.4962322',
#   'lon': '-73.9756293',
#   'poblacion': 19195.0,
#   'riesgo': 'ALTO'},
#  'Ayapel': {'departamento': 'Córdoba',
#   'lat': '8.27184485',
#   'lon': '-75.0456642109153',
#   'poblacion': 51164.0,
#   'riesgo': 'BAJO'},
#  'Balboa': {'departamento': 'Risaralda',
#   'lat': '4.9510551',
#   'lon': '-75.9591466',
#   'poblacion': 6331.0,
#   'riesgo': 'MEDIO'},
#  'Baranoa': {'departamento': 'Atlántico',
#   'lat': '10.78069155',
#   'lon': '-74.9164405686805',
#   'poblacion': 57845.0,
#   'riesgo': 'MEDIO'},
#  'Baraya': {'departamento': 'Huila',
#   'lat': '3.0884886',
#   'lon': '-74.9444145032746',
#   'poblacion': 9610.0,
#   'riesgo': 'ALTO'},
#  'Barbacoas': {'departamento': 'Nariño',
#   'lat': '1.49613655',
#   'lon': '-78.0764462033363',
#   'poblacion': 37851.0,
#   'riesgo': 'ALTO'},
#  'Barbosa': {'departamento': 'Santander',
#   'lat': '5.9328785',
#   'lon': '-73.6140874',
#   'poblacion': 28635.0,
#   'riesgo': 'MEDIO'},
#  'Barichara': {'departamento': 'Santander',
#   'lat': '6.64967285',
#   'lon': '-73.2264517346614',
#   'poblacion': 7215.0,
#   'riesgo': 'SIN RIESGO'},
#  'Barranca De Upía': {'departamento': 'Meta',
#   'lat': '4.5656099',
#   'lon': '-72.960156934477',
#   'poblacion': 3926.0,
#   'riesgo': 'MEDIO'},
#  'Barrancabermeja': {'departamento': 'Santander',
#   'lat': '7.02691215',
#   'lon': '-73.75919805297',
#   'poblacion': 191768.0,
#   'riesgo': 'SIN RIESGO'},
#  'Barrancas': {'departamento': 'La Guajira',
#   'lat': '10.9782843',
#   'lon': '-72.6961176191123',
#   'poblacion': 34619.0,
#   'riesgo': 'ALTO'},
#  'Barranco De Loba': {'departamento': 'Bolívar',
#   'lat': '8.9442603',
#   'lon': '-74.1059488',
#   'poblacion': 17768.0,
#   'riesgo': 'ALTO'},
#  'Barranco Minas': {'departamento': 'Guainía',
#   'lat': '3.4942395',
#   'lon': '-69.8132615',
#   'poblacion': 4862.0,
#   'riesgo': 'ALTO'},
#  'Barranquilla': {'departamento': 'Atlántico',
#   'lat': '10.9799669',
#   'lon': '-74.8013085',
#   'poblacion': 1218737.0,
#   'riesgo': 'SIN RIESGO'},
#  'Becerril': {'departamento': 'Cesar',
#   'lat': '9.75308145',
#   'lon': '-73.2438016723873',
#   'poblacion': 13453.0,
#   'riesgo': 'MEDIO'},
#  'Belalcázar': {'departamento': 'Caldas',
#   'lat': '4.9965888',
#   'lon': '-75.8238756000794',
#   'poblacion': 10863.0,
#   'riesgo': 'ALTO'},
#  'Bello': {'departamento': 'Antioquia',
#   'lat': '6.36117455',
#   'lon': '-75.589713296052',
#   'poblacion': 455807.0,
#   'riesgo': 'SIN RIESGO'},
#  'Belmira': {'departamento': 'Antioquia',
#   'lat': '6.64687305',
#   'lon': '-75.6879047756093',
#   'poblacion': 6760.0,
#   'riesgo': 'SIN RIESGO'},
#  'Beltrán': {'departamento': 'Cundinamarca',
#   'lat': '4.71435715',
#   'lon': '-74.7792052766098',
#   'poblacion': 2197.0,
#   'riesgo': 'MEDIO'},
#  'Belén': {'departamento': 'Nariño',
#   'lat': '1.59533345',
#   'lon': '-77.0272666250245',
#   'poblacion': 7518.0,
#   'riesgo': 'ALTO'},
#  'Belén De Los Andaquíes': {'departamento': 'Caquetá',
#   'lat': '1.4636189',
#   'lon': '-75.8908508248569',
#   'poblacion': 11541.0,
#   'riesgo': 'SIN RIESGO'},
#  'Belén De Umbría': {'departamento': 'Risaralda',
#   'lat': '5.1894267',
#   'lon': '-75.8697146858765',
#   'poblacion': 27721.0,
#   'riesgo': 'MEDIO'},
#  'Berbeo': {'departamento': 'Boyacá',
#   'lat': '5.22944595',
#   'lon': '-73.1261719421096',
#   'poblacion': 8100.0,
#   'riesgo': 'ALTO'},
#  'Betania': {'departamento': 'Antioquia',
#   'lat': '5.73407355',
#   'lon': '-75.9820513388304',
#   'poblacion': 9286.0,
#   'riesgo': 'SIN RIESGO'},
#  'Betulia': {'departamento': 'Santander',
#   'lat': '6.8997683',
#   'lon': '-73.2838219',
#   'poblacion': 5110.0,
#   'riesgo': 'BAJO'},
#  'Betéitiva': {'departamento': 'Boyacá',
#   'lat': '5.9222597',
#   'lon': '-72.8589403097732',
#   'poblacion': 2069.0,
#   'riesgo': 'ALTO'},
#  'Bituima': {'departamento': 'Cundinamarca',
#   'lat': '4.8691261',
#   'lon': '-74.5222867916663',
#   'poblacion': 2520.0,
#   'riesgo': 'BAJO'},
#  'Boavita': {'departamento': 'Boyacá',
#   'lat': '6.33216125',
#   'lon': '-72.6095100987069',
#   'poblacion': 7079.0,
#   'riesgo': 'ALTO'},
#  'Bochalema': {'departamento': 'Norte de Santander',
#   'lat': '7.644363',
#   'lon': '-72.6538619299259',
#   'poblacion': 6973.0,
#   'riesgo': 'MEDIO'},
#  'Bogotá DC': {'departamento': 'Bogotá DC',
#   'lat': '4.59808',
#   'lon': '-74.0760439',
#   'poblacion': 7878783.0,
#   'riesgo': 'BAJO'},
#  'Bojacá': {'departamento': 'Cundinamarca',
#   'lat': '4.6904795',
#   'lon': '-74.3257575691398',
#   'poblacion': 11555.0,
#   'riesgo': 'MEDIO'},
#  'Bolívar': {'departamento': 'Valle del Cauca',
#   'lat': '4.3371598',
#   'lon': '-76.1847481',
#   'poblacion': 13474.0,
#   'riesgo': 'ALTO'},
#  'Bosconia': {'departamento': 'Cesar',
#   'lat': '9.9284449',
#   'lon': '-73.8587145291547',
#   'poblacion': 37248.0,
#   'riesgo': 'ALTO'},
#  'Boyacá': {'departamento': 'Boyacá',
#   'lat': '5.4545233',
#   'lon': '-73.3615406',
#   'poblacion': 10099.0,
#   'riesgo': 'ALTO'},
#  'Briceño': {'departamento': 'Boyacá',
#   'lat': '5.6908712',
#   'lon': '-73.9234546',
#   'poblacion': 2584.0,
#   'riesgo': 'ALTO'},
#  'Bucaramanga': {'departamento': 'Santander',
#   'lat': '7.1114611',
#   'lon': '-73.1172869',
#   'poblacion': 527985.0,
#   'riesgo': 'SIN RIESGO'},
#  'Bucarasica': {'departamento': 'Norte de Santander',
#   'lat': '8.0649425',
#   'lon': '-72.9391079',
#   'poblacion': 4570.0,
#   'riesgo': 'MEDIO'},
#  'Buenaventura': {'departamento': 'Valle del Cauca',
#   'lat': '3.6707494',
#   'lon': '-76.9807757700535',
#   'poblacion': 399619.0,
#   'riesgo': 'BAJO'},
#  'Buenavista': {'departamento': 'Sucre',
#   'lat': '9.3196186',
#   'lon': '-74.9745867',
#   'poblacion': 9552.0,
#   'riesgo': 'MEDIO'},
#  'Buenos Aires': {'departamento': 'Cauca',
#   'lat': '3.39298005',
#   'lon': '-76.5497768553552',
#   'poblacion': 32225.0,
#   'riesgo': 'BAJO'},
#  'Buesaco': {'departamento': 'Nariño',
#   'lat': '1.3292917',
#   'lon': '-77.123151775',
#   'poblacion': 25063.0,
#   'riesgo': 'ALTO'},
#  'Bugalagrande': {'departamento': 'Valle del Cauca',
#   'lat': '4.201411',
#   'lon': '-76.0970158974797',
#   'poblacion': 21167.0,
#   'riesgo': 'MEDIO'},
#  'Buriticá': {'departamento': 'Antioquia',
#   'lat': '6.80627485',
#   'lon': '-75.9217307243866',
#   'poblacion': 6601.0,
#   'riesgo': 'SIN RIESGO'},
#  'Busbanza': {'departamento': 'Boyacá',
#   'lat': '5.8507677',
#   'lon': '-72.8744038281345',
#   'poblacion': 1156.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cabrera': {'departamento': 'Santander',
#   'lat': '6.5933521',
#   'lon': '-73.2463975',
#   'poblacion': 2267.0,
#   'riesgo': 'BAJO'},
#  'Cabuyaro': {'departamento': 'Meta',
#   'lat': '4.2887655',
#   'lon': '-72.7898901',
#   'poblacion': 4018.0,
#   'riesgo': 'MEDIO'},
#  'Cachipay': {'departamento': 'Cundinamarca',
#   'lat': '4.72885605',
#   'lon': '-74.4607835600324',
#   'poblacion': 9833.0,
#   'riesgo': 'BAJO'},
#  'Cachirá': {'departamento': 'Norte de Santander',
#   'lat': '7.7419001',
#   'lon': '-73.0485225',
#   'poblacion': 10970.0,
#   'riesgo': 'MEDIO'},
#  'Caicedo': {'departamento': 'Antioquia',
#   'lat': '6.42595665',
#   'lon': '-75.992108112588',
#   'poblacion': 8205.0,
#   'riesgo': 'SIN RIESGO'},
#  'Caicedonia': {'departamento': 'Valle del Cauca',
#   'lat': '4.305471',
#   'lon': '-75.8404757042712',
#   'poblacion': 29824.0,
#   'riesgo': 'MEDIO'},
#  'Caimito': {'departamento': 'Sucre',
#   'lat': '8.790591',
#   'lon': '-75.1163176',
#   'poblacion': 12077.0,
#   'riesgo': 'MEDIO'},
#  'Cajibío': {'departamento': 'Cauca',
#   'lat': '2.655067',
#   'lon': '-76.7165015826487',
#   'poblacion': 37522.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cajicá': {'departamento': 'Cundinamarca',
#   'lat': '4.9172215',
#   'lon': '-74.0255474',
#   'poblacion': 56875.0,
#   'riesgo': 'SIN RIESGO'},
#  'Calamar': {'departamento': 'Bolívar',
#   'lat': '10.2526122',
#   'lon': '-74.9146691',
#   'poblacion': 9091.0,
#   'riesgo': 'MEDIO'},
#  'Calarca': {'departamento': 'Quindio',
#   'lat': '4.5299057',
#   'lon': '-75.6402893',
#   'poblacion': 19656.0,
#   'riesgo': 'SIN RIESGO'},
#  'Caldas': {'departamento': 'Boyacá',
#   'lat': '5.5544872',
#   'lon': '-73.8653516',
#   'poblacion': 3638.0,
#   'riesgo': 'MEDIO'},
#  'Caldono': {'departamento': 'Cauca',
#   'lat': '2.796326',
#   'lon': '-76.4836526',
#   'poblacion': 33122.0,
#   'riesgo': 'MEDIO'},
#  'Cali': {'departamento': 'Valle del Cauca',
#   'lat': '3.4517923',
#   'lon': '-76.5324943',
#   'poblacion': 2369829.0,
#   'riesgo': 'SIN RIESGO'},
#  'California': {'departamento': 'Santander',
#   'lat': '2.9067539',
#   'lon': '-76.4732713',
#   'poblacion': 1984.0,
#   'riesgo': 'SIN RIESGO'},
#  'Calima': {'departamento': 'Valle del Cauca',
#   'lat': '3.4848867',
#   'lon': '-76.4999017280985',
#   'poblacion': 15763.0,
#   'riesgo': 'ALTO'},
#  'Caloto': {'departamento': 'Cauca',
#   'lat': '3.04497365',
#   'lon': '-76.3685084856608',
#   'poblacion': 17642.0,
#   'riesgo': 'ALTO'},
#  'Campamento': {'departamento': 'Antioquia',
#   'lat': '7.07756515',
#   'lon': '-75.2943432655889',
#   'poblacion': 9091.0,
#   'riesgo': 'SIN RIESGO'},
#  'Campo De La Cruz': {'departamento': 'Atlántico',
#   'lat': '10.3801633',
#   'lon': '-74.8814116',
#   'poblacion': 16035.0,
#   'riesgo': 'ALTO'},
#  'Campoalegre': {'departamento': 'Huila',
#   'lat': '2.6454014',
#   'lon': '-75.3247179139157',
#   'poblacion': 34309.0,
#   'riesgo': 'ALTO'},
#  'Campohermoso': {'departamento': 'Boyacá',
#   'lat': '4.9980278',
#   'lon': '-73.1203747840196',
#   'poblacion': 3847.0,
#   'riesgo': 'SIN RIESGO'},
#  'Canalete': {'departamento': 'Córdoba',
#   'lat': '8.7128498',
#   'lon': '-76.2520252957378',
#   'poblacion': 21548.0,
#   'riesgo': 'ALTO'},
#  'Candelaria': {'departamento': 'Valle del Cauca',
#   'lat': '3.4090481',
#   'lon': '-76.347379',
#   'poblacion': 81697.0,
#   'riesgo': 'BAJO'},
#  'Cantagallo': {'departamento': 'Bolívar',
#   'lat': '7.3780007',
#   'lon': '-73.9150265',
#   'poblacion': 9239.0,
#   'riesgo': 'ALTO'},
#  'Caparrapí': {'departamento': 'Cundinamarca',
#   'lat': '5.37362775',
#   'lon': '-74.5260218880582',
#   'poblacion': 47195.0,
#   'riesgo': 'MEDIO'},
#  'Capitanejo': {'departamento': 'Santander',
#   'lat': '6.5149284',
#   'lon': '-72.6743387624081',
#   'poblacion': 5593.0,
#   'riesgo': 'MEDIO'},
#  'Caqueza': {'departamento': 'Cundinamarca',
#   'lat': '4.39774645',
#   'lon': '-73.9450047049864',
#   'poblacion': 17048.0,
#   'riesgo': 'SIN RIESGO'},
#  'Caracolí': {'departamento': 'Antioquia',
#   'lat': '6.4092756',
#   'lon': '-74.7566979',
#   'poblacion': 4595.0,
#   'riesgo': 'SIN RIESGO'},
#  'Caramanta': {'departamento': 'Antioquia',
#   'lat': '5.56200475',
#   'lon': '-75.6341883366136',
#   'poblacion': 5362.0,
#   'riesgo': 'SIN RIESGO'},
#  'Carcasí': {'departamento': 'Santander',
#   'lat': '6.658389',
#   'lon': '-72.5667056758176',
#   'poblacion': 5039.0,
#   'riesgo': 'BAJO'},
#  'Carepa': {'departamento': 'Antioquia',
#   'lat': '7.7977584',
#   'lon': '-76.7455146179126',
#   'poblacion': 55788.0,
#   'riesgo': 'SIN RIESGO'},
#  'Carmen De Carupa': {'departamento': 'Cundinamarca',
#   'lat': '5.3485046',
#   'lon': '-73.9016622',
#   'poblacion': 9109.0,
#   'riesgo': 'SIN RIESGO'},
#  'Carolina': {'departamento': 'Antioquia',
#   'lat': '6.7501787',
#   'lon': '-75.3229229277351',
#   'poblacion': 3629.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cartagena': {'departamento': 'Bolívar',
#   'lat': '10.4195841',
#   'lon': '-75.5271224',
#   'poblacion': 33391.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cartago': {'departamento': 'Valle del Cauca',
#   'lat': '4.71133845',
#   'lon': '-75.9319330890169',
#   'poblacion': 132251.0,
#   'riesgo': 'BAJO'},
#  'Caruru': {'departamento': 'Vaupés',
#   'lat': '1.5524104',
#   'lon': '-70.2038516',
#   'poblacion': 3327.0,
#   'riesgo': 'SIN RIESGO'},
#  'Casabianca': {'departamento': 'Tolima',
#   'lat': '5.0784062',
#   'lon': '-75.1213073',
#   'poblacion': 6684.0,
#   'riesgo': 'SIN RIESGO'},
#  'Castilla La Nueva': {'departamento': 'Meta',
#   'lat': '3.8275343',
#   'lon': '-73.6892805',
#   'poblacion': 9612.0,
#   'riesgo': 'MEDIO'},
#  'Caucasia': {'departamento': 'Antioquia',
#   'lat': '7.82747905',
#   'lon': '-75.0452149149027',
#   'poblacion': 112168.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cañasgordas': {'departamento': 'Antioquia',
#   'lat': '6.8140438',
#   'lon': '-76.0462452454564',
#   'poblacion': 16763.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cepitá': {'departamento': 'Santander',
#   'lat': '6.74590095',
#   'lon': '-72.9294288166832',
#   'poblacion': 1865.0,
#   'riesgo': 'BAJO'},
#  'Cereté': {'departamento': 'Córdoba',
#   'lat': '8.8884178',
#   'lon': '-75.8423945657266',
#   'poblacion': 91525.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cerinza': {'departamento': 'Boyacá',
#   'lat': '5.97102995',
#   'lon': '-72.9681475205072',
#   'poblacion': 3762.0,
#   'riesgo': 'MEDIO'},
#  'Cerrito': {'departamento': 'Santander',
#   'lat': '6.8435992',
#   'lon': '-72.6939627',
#   'poblacion': 5708.0,
#   'riesgo': 'MEDIO'},
#  'Cerro San Antonio': {'departamento': 'Magdalena',
#   'lat': '5.6417923',
#   'lon': '-74.9650465',
#   'poblacion': 14400.0,
#   'riesgo': 'MEDIO'},
#  'Chachagüí': {'departamento': 'Nariño',
#   'lat': '1.4051167',
#   'lon': '-77.2743657529271',
#   'poblacion': 13784.0,
#   'riesgo': 'ALTO'},
#  'Chaguaní': {'departamento': 'Cundinamarca',
#   'lat': '4.94902105',
#   'lon': '-74.6259925457383',
#   'poblacion': 3981.0,
#   'riesgo': 'BAJO'},
#  'Chalán': {'departamento': 'Sucre',
#   'lat': '9.57205555',
#   'lon': '-75.3224638374139',
#   'poblacion': 4354.0,
#   'riesgo': 'BAJO'},
#  'Chameza': {'departamento': 'Casanare',
#   'lat': '5.2358115',
#   'lon': '-72.8708766727443',
#   'poblacion': 2460.0,
#   'riesgo': 'MEDIO'},
#  'Charalá': {'departamento': 'Santander',
#   'lat': '6.1869866',
#   'lon': '-73.1834347888072',
#   'poblacion': 10540.0,
#   'riesgo': 'SIN RIESGO'},
#  'Charta': {'departamento': 'Santander',
#   'lat': '7.25253105',
#   'lon': '-72.9765964163482',
#   'poblacion': 2670.0,
#   'riesgo': 'MEDIO'},
#  'Chibolo': {'departamento': 'Magdalena',
#   'lat': '10.0889797',
#   'lon': '-74.5113823303251',
#   'poblacion': 15960.0,
#   'riesgo': 'ALTO'},
#  'Chigorodó': {'departamento': 'Antioquia',
#   'lat': '7.61241355',
#   'lon': '-76.6359403826695',
#   'poblacion': 76202.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chima': {'departamento': 'Santander',
#   'lat': '6.3418537',
#   'lon': '-73.3728984',
#   'poblacion': 3087.0,
#   'riesgo': 'BAJO'},
#  'Chimichagua': {'departamento': 'Cesar',
#   'lat': '9.2380455',
#   'lon': '-73.8200515024227',
#   'poblacion': 30658.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chimá': {'departamento': 'Córdoba',
#   'lat': '9.10226505',
#   'lon': '-75.6593813329333',
#   'poblacion': 15018.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chinavita': {'departamento': 'Boyacá',
#   'lat': '5.2062439',
#   'lon': '-73.3349582226619',
#   'poblacion': 3528.0,
#   'riesgo': 'ALTO'},
#  'Chinchiná': {'departamento': 'Caldas',
#   'lat': '5.0353872',
#   'lon': '-75.5314733',
#   'poblacion': 51492.0,
#   'riesgo': 'MEDIO'},
#  'Chinácota': {'departamento': 'Norte de Santander',
#   'lat': '7.5779229',
#   'lon': '-72.5974892069276',
#   'poblacion': 16348.0,
#   'riesgo': 'MEDIO'},
#  'Chinú': {'departamento': 'Córdoba',
#   'lat': '9.02310485',
#   'lon': '-75.3866274941264',
#   'poblacion': 48304.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chipaque': {'departamento': 'Cundinamarca',
#   'lat': '4.4073852',
#   'lon': '-74.0860577629755',
#   'poblacion': 8400.0,
#   'riesgo': 'BAJO'},
#  'Chipatá': {'departamento': 'Santander',
#   'lat': '6.07416435',
#   'lon': '-73.6301297828965',
#   'poblacion': 5088.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chiquinquirá': {'departamento': 'Boyacá',
#   'lat': '5.62955415',
#   'lon': '-73.7737122500415',
#   'poblacion': 65274.0,
#   'riesgo': 'BAJO'},
#  'Chiriguaná': {'departamento': 'Cesar',
#   'lat': '9.3636401',
#   'lon': '-73.6016974',
#   'poblacion': 19650.0,
#   'riesgo': 'ALTO'},
#  'Chiscas': {'departamento': 'Boyacá',
#   'lat': '6.6767804',
#   'lon': '-72.4067438586216',
#   'poblacion': 4291.0,
#   'riesgo': 'ALTO'},
#  'Chita': {'departamento': 'Boyacá',
#   'lat': '6.1871968',
#   'lon': '-72.4729374',
#   'poblacion': 9542.0,
#   'riesgo': 'BAJO'},
#  'Chitagá': {'departamento': 'Norte de Santander',
#   'lat': '7.06863155',
#   'lon': '-72.5373897377475',
#   'poblacion': 10373.0,
#   'riesgo': 'MEDIO'},
#  'Chitaraque': {'departamento': 'Boyacá',
#   'lat': '5.9818101',
#   'lon': '-73.429164913034',
#   'poblacion': 5687.0,
#   'riesgo': 'MEDIO'},
#  'Chivatá': {'departamento': 'Boyacá',
#   'lat': '5.5803634',
#   'lon': '-73.2486620183388',
#   'poblacion': 6199.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chivor': {'departamento': 'Boyacá',
#   'lat': '4.8880351',
#   'lon': '-73.3683236',
#   'poblacion': 1795.0,
#   'riesgo': 'ALTO'},
#  'Choachí': {'departamento': 'Cundinamarca',
#   'lat': '4.57759445',
#   'lon': '-73.920546002545',
#   'poblacion': 10729.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chocontá': {'departamento': 'Cundinamarca',
#   'lat': '5.1459409',
#   'lon': '-73.6839512',
#   'poblacion': 25257.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chía': {'departamento': 'Cundinamarca',
#   'lat': '4.8612976',
#   'lon': '-74.0599286',
#   'poblacion': 126647.0,
#   'riesgo': 'SIN RIESGO'},
#  'Chíquiza': {'departamento': 'Boyacá',
#   'lat': '5.6361306',
#   'lon': '-73.4423419889523',
#   'poblacion': 5484.0,
#   'riesgo': 'MEDIO'},
#  'Cicuco': {'departamento': 'Bolívar',
#   'lat': '9.2368961',
#   'lon': '-74.6936885600984',
#   'poblacion': 11118.0,
#   'riesgo': 'ALTO'},
#  'Cimitarra': {'departamento': 'Santander',
#   'lat': '6.42419845',
#   'lon': '-74.0920370496232',
#   'poblacion': 44733.0,
#   'riesgo': 'MEDIO'},
#  'Circasia': {'departamento': 'Quindio',
#   'lat': '4.6113471',
#   'lon': '-75.6624256638335',
#   'poblacion': 29886.0,
#   'riesgo': 'BAJO'},
#  'Cisneros': {'departamento': 'Antioquia',
#   'lat': '6.54495605',
#   'lon': '-75.080189676878',
#   'poblacion': 9058.0,
#   'riesgo': 'INVIABLE SANITARIAMENTE'},
#  'Ciudad Bolívar': {'departamento': 'Antioquia',
#   'lat': '5.8500342',
#   'lon': '-76.0208666',
#   'poblacion': 27084.0,
#   'riesgo': 'SIN RIESGO'},
#  'Ciénaga': {'departamento': 'Magdalena',
#   'lat': '10.8567448',
#   'lon': '-73.9538368494131',
#   'poblacion': 104319.0,
#   'riesgo': 'SIN RIESGO'},
#  'Ciénega': {'departamento': 'Boyacá',
#   'lat': '5.38862195',
#   'lon': '-73.278040294047',
#   'poblacion': 4754.0,
#   'riesgo': 'ALTO'},
#  'Clemencia': {'departamento': 'Bolívar',
#   'lat': '10.56180475',
#   'lon': '-75.3295539371322',
#   'poblacion': 12540.0,
#   'riesgo': 'ALTO'},
#  'Cocorná': {'departamento': 'Antioquia',
#   'lat': '6.00398715',
#   'lon': '-75.1362078336584',
#   'poblacion': 14972.0,
#   'riesgo': 'BAJO'},
#  'Cogua': {'departamento': 'Cundinamarca',
#   'lat': '5.11297315',
#   'lon': '-73.9579827086912',
#   'poblacion': 22361.0,
#   'riesgo': 'MEDIO'},
#  'Colombia': {'departamento': 'Huila',
#   'lat': '2.4738993',
#   'lon': '-75.5900113',
#   'poblacion': 12413.0,
#   'riesgo': 'ALTO'},
#  'Coloso': {'departamento': 'Sucre',
#   'lat': '9.53763835',
#   'lon': '-75.3636628711197',
#   'poblacion': 5838.0,
#   'riesgo': 'SIN RIESGO'},
#  'Colón': {'departamento': 'Putumayo',
#   'lat': '1.1894909',
#   'lon': '-76.9725122',
#   'poblacion': 5519.0,
#   'riesgo': 'MEDIO'},
#  'Concepción': {'departamento': 'Santander',
#   'lat': '6.8014661',
#   'lon': '-72.5370422481365',
#   'poblacion': 5292.0,
#   'riesgo': 'MEDIO'},
#  'Concordia': {'departamento': 'Magdalena',
#   'lat': '10.23088415',
#   'lon': '-74.7586240534815',
#   'poblacion': 9388.0,
#   'riesgo': 'ALTO'},
#  'Confines': {'departamento': 'Santander',
#   'lat': '6.3623424',
#   'lon': '-73.249841261314',
#   'poblacion': 2705.0,
#   'riesgo': 'BAJO'},
#  'Consaca': {'departamento': 'Nariño',
#   'lat': '1.2082795',
#   'lon': '-77.4656149',
#   'poblacion': 9386.0,
#   'riesgo': 'ALTO'},
#  'Contadero': {'departamento': 'Nariño',
#   'lat': '0.927464',
#   'lon': '-77.5219475338443',
#   'poblacion': 6954.0,
#   'riesgo': 'ALTO'},
#  'Contratación': {'departamento': 'Santander',
#   'lat': '6.30365295',
#   'lon': '-73.5215840157677',
#   'poblacion': 3491.0,
#   'riesgo': 'MEDIO'},
#  'Convención': {'departamento': 'Norte de Santander',
#   'lat': '8.5833769',
#   'lon': '-73.2830742',
#   'poblacion': 13569.0,
#   'riesgo': 'ALTO'},
#  'Copacabana': {'departamento': 'Antioquia',
#   'lat': '6.3600462',
#   'lon': '-75.4978699738914',
#   'poblacion': 70171.0,
#   'riesgo': 'SIN RIESGO'},
#  'Coper': {'departamento': 'Boyacá',
#   'lat': '5.4757954',
#   'lon': '-74.0452233',
#   'poblacion': 3663.0,
#   'riesgo': 'ALTO'},
#  'Corinto': {'departamento': 'Cauca',
#   'lat': '3.1733723',
#   'lon': '-76.2600266',
#   'poblacion': 14660.0,
#   'riesgo': 'SIN RIESGO'},
#  'Coromoro': {'departamento': 'Santander',
#   'lat': '6.24050595',
#   'lon': '-72.9917307037051',
#   'poblacion': 7558.0,
#   'riesgo': 'MEDIO'},
#  'Corozal': {'departamento': 'Sucre',
#   'lat': '9.3192389',
#   'lon': '-75.2947262',
#   'poblacion': 62409.0,
#   'riesgo': 'SIN RIESGO'},
#  'Corrales': {'departamento': 'Boyacá',
#   'lat': '5.8286152',
#   'lon': '-72.8444774',
#   'poblacion': 2273.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cota': {'departamento': 'Cundinamarca',
#   'lat': '4.8093624',
#   'lon': '-74.1015739',
#   'poblacion': 24916.0,
#   'riesgo': 'BAJO'},
#  'Cotorra': {'departamento': 'Córdoba',
#   'lat': '9.0615385',
#   'lon': '-75.7611567501981',
#   'poblacion': 15447.0,
#   'riesgo': 'MEDIO'},
#  'Covarachía': {'departamento': 'Boyacá',
#   'lat': '6.51198805',
#   'lon': '-72.7319045427829',
#   'poblacion': 2861.0,
#   'riesgo': 'MEDIO'},
#  'Coveñas': {'departamento': 'Sucre',
#   'lat': '9.41146205',
#   'lon': '-75.639789293312',
#   'poblacion': 13530.0,
#   'riesgo': 'BAJO'},
#  'Cravo Norte': {'departamento': 'Arauca',
#   'lat': '6.5246851',
#   'lon': '-71.7320704',
#   'poblacion': 3331.0,
#   'riesgo': 'BAJO'},
#  'Cuaspud': {'departamento': 'Nariño',
#   'lat': '0.87509105',
#   'lon': '-77.7420113843592',
#   'poblacion': 8592.0,
#   'riesgo': 'ALTO'},
#  'Cubarral': {'departamento': 'Meta',
#   'lat': '3.8062823',
#   'lon': '-73.8443539',
#   'poblacion': 5946.0,
#   'riesgo': 'ALTO'},
#  'Cubará': {'departamento': 'Boyacá',
#   'lat': '7.0007084',
#   'lon': '-72.1079562',
#   'poblacion': 6725.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cucaita': {'departamento': 'Boyacá',
#   'lat': '5.5431182',
#   'lon': '-73.4547788',
#   'poblacion': 4687.0,
#   'riesgo': 'ALTO'},
#  'Cucunubá': {'departamento': 'Cundinamarca',
#   'lat': '5.2502785',
#   'lon': '-73.7664625',
#   'poblacion': 7479.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cucutilla': {'departamento': 'Norte de Santander',
#   'lat': '7.49960565',
#   'lon': '-72.7766245432376',
#   'poblacion': 7686.0,
#   'riesgo': 'ALTO'},
#  'Cumaral': {'departamento': 'Meta',
#   'lat': '4.2681176',
#   'lon': '-73.4869533',
#   'poblacion': 18020.0,
#   'riesgo': 'MEDIO'},
#  'Cumaribo': {'departamento': 'Vichada',
#   'lat': '4.4471495',
#   'lon': '-69.7975845',
#   'poblacion': 36867.0,
#   'riesgo': 'ALTO'},
#  'Cumbal': {'departamento': 'Nariño',
#   'lat': '0.9396153',
#   'lon': '-77.9922470796222',
#   'poblacion': 37635.0,
#   'riesgo': 'ALTO'},
#  'Cumbitara': {'departamento': 'Nariño',
#   'lat': '1.7410705',
#   'lon': '-77.5962311499926',
#   'poblacion': 15239.0,
#   'riesgo': 'ALTO'},
#  'Curillo': {'departamento': 'Caquetá',
#   'lat': '1.0624341',
#   'lon': '-75.9181033507946',
#   'poblacion': 5029.0,
#   'riesgo': 'MEDIO'},
#  'Curití': {'departamento': 'Santander',
#   'lat': '6.61280515',
#   'lon': '-73.0168786933379',
#   'poblacion': 11899.0,
#   'riesgo': 'BAJO'},
#  'Curumaní': {'departamento': 'Cesar',
#   'lat': '9.1995316',
#   'lon': '-73.5440609',
#   'poblacion': 24367.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cuítiva': {'departamento': 'Boyacá',
#   'lat': '5.58728115',
#   'lon': '-72.9500854223374',
#   'poblacion': 1906.0,
#   'riesgo': 'BAJO'},
#  'Cáceres': {'departamento': 'Antioquia',
#   'lat': '7.582364',
#   'lon': '-75.3477905',
#   'poblacion': 37806.0,
#   'riesgo': 'MEDIO'},
#  'Cácota': {'departamento': 'Norte de Santander',
#   'lat': '7.2597706',
#   'lon': '-72.6557234511297',
#   'poblacion': 1925.0,
#   'riesgo': 'ALTO'},
#  'Cértegui': {'departamento': 'Chocó',
#   'lat': '5.38214415',
#   'lon': '-76.5204998673726',
#   'poblacion': 10068.0,
#   'riesgo': 'MEDIO'},
#  'Cómbita': {'departamento': 'Boyacá',
#   'lat': '5.69042285',
#   'lon': '-73.309196641478',
#   'poblacion': 7957.0,
#   'riesgo': 'BAJO'},
#  'Córdoba': {'departamento': 'Quindio',
#   'lat': '4.3901949',
#   'lon': '-75.6854978',
#   'poblacion': 5305.0,
#   'riesgo': 'SIN RIESGO'},
#  'Cúcuta': {'departamento': 'Norte de Santander',
#   'lat': '7.8971458',
#   'lon': '-72.5080387',
#   'poblacion': 649983.0,
#   'riesgo': 'SIN RIESGO'},
#  'Dabeiba': {'departamento': 'Antioquia',
#   'lat': '7.0015209',
#   'lon': '-76.2666243',
#   'poblacion': 23378.0,
#   'riesgo': 'SIN RIESGO'},
#  'Dagua': {'departamento': 'Valle del Cauca',
#   'lat': '3.65186675',
#   'lon': '-76.7228927151123',
#   'poblacion': 36400.0,
#   'riesgo': 'ALTO'},
#  'Dibulla': {'departamento': 'La Guajira',
#   'lat': '11.0829542',
#   'lon': '-73.4472323664315',
#   'poblacion': 32983.0,
#   'riesgo': 'INVIABLE SANITARIAMENTE'},
#  'Distracción': {'departamento': 'La Guajira',
#   'lat': '10.8993688',
#   'lon': '-72.8875669',
#   'poblacion': 15790.0,
#   'riesgo': 'BAJO'},
#  'Don Matías': {'departamento': 'Antioquia',
#   'lat': '6.5023341',
#   'lon': '-75.3945705947052',
#   'poblacion': 22243.0,
#   'riesgo': 'SIN RIESGO'},
#  'Dosquebradas': {'departamento': 'Risaralda',
#   'lat': '4.8397374',
#   'lon': '-75.672696893989',
#   'poblacion': 198874.0,
#   'riesgo': 'MEDIO'},
#  'Duitama': {'departamento': 'Boyacá',
#   'lat': '5.8277055',
#   'lon': '-73.0338939',
#   'poblacion': 112692.0,
#   'riesgo': 'MEDIO'},
#  'Durania': {'departamento': 'Norte de Santander',
#   'lat': '7.7141729',
#   'lon': '-72.6566936',
#   'poblacion': 3768.0,
#   'riesgo': 'MEDIO'},
#  'Ebéjico': {'departamento': 'Antioquia',
#   'lat': '6.3219859',
#   'lon': '-75.7831532590167',
#   'poblacion': 12515.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Bagre': {'departamento': 'Antioquia',
#   'lat': '7.6977101',
#   'lon': '-74.6222028245339',
#   'poblacion': 49583.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Banco': {'departamento': 'Magdalena',
#   'lat': '8.9953753',
#   'lon': '-73.9723091',
#   'poblacion': 55530.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Cairo': {'departamento': 'Valle del Cauca',
#   'lat': '4.7621884',
#   'lon': '-76.2207611',
#   'poblacion': 9976.0,
#   'riesgo': 'ALTO'},
#  'El Calvario': {'departamento': 'Meta',
#   'lat': '4.3527082',
#   'lon': '-73.7141414',
#   'poblacion': 2240.0,
#   'riesgo': 'ALTO'},
#  'El Carmen': {'departamento': 'Norte de Santander',
#   'lat': '8.6473135',
#   'lon': '-73.4082035',
#   'poblacion': 14005.0,
#   'riesgo': 'MEDIO'},
#  'El Carmen De Bolívar': {'departamento': 'Bolívar',
#   'lat': '9.7178623',
#   'lon': '-75.1238318',
#   'poblacion': 75151.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Carmen De Chucurí': {'departamento': 'Santander',
#   'lat': '6.6986924',
#   'lon': '-73.5115695',
#   'poblacion': 20099.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Carmen De Viboral': {'departamento': 'Antioquia',
#   'lat': '5.98195145',
#   'lon': '-75.2607801425401',
#   'poblacion': 8793.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Castillo': {'departamento': 'Meta',
#   'lat': '3.5647959',
#   'lon': '-73.7942913',
#   'poblacion': 6362.0,
#   'riesgo': 'INVIABLE SANITARIAMENTE'},
#  'El Cerrito': {'departamento': 'Valle del Cauca',
#   'lat': '3.6829185',
#   'lon': '-76.3071487',
#   'poblacion': 57463.0,
#   'riesgo': 'BAJO'},
#  'El Charco': {'departamento': 'Nariño',
#   'lat': '2.4771921',
#   'lon': '-78.110211',
#   'poblacion': 36856.0,
#   'riesgo': 'ALTO'},
#  'El Cocuy': {'departamento': 'Boyacá',
#   'lat': '6.4076711',
#   'lon': '-72.4457503',
#   'poblacion': 5241.0,
#   'riesgo': 'MEDIO'},
#  'El Colegio': {'departamento': 'Cundinamarca',
#   'lat': '4.5809252',
#   'lon': '-74.4416222',
#   'poblacion': 21832.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Copey': {'departamento': 'Cesar',
#   'lat': '10.2030142',
#   'lon': '-73.916175014053',
#   'poblacion': 26473.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Doncello': {'departamento': 'Caquetá',
#   'lat': '1.6815919',
#   'lon': '-75.2844565',
#   'poblacion': 22137.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Dorado': {'departamento': 'Meta',
#   'lat': '3.7335285',
#   'lon': '-73.5764641',
#   'poblacion': 3429.0,
#   'riesgo': 'MEDIO'},
#  'El Dovio': {'departamento': 'Valle del Cauca',
#   'lat': '4.511899',
#   'lon': '-76.238102',
#   'poblacion': 8508.0,
#   'riesgo': 'ALTO'},
#  'El Espino': {'departamento': 'Boyacá',
#   'lat': '6.4825581',
#   'lon': '-72.4952026',
#   'poblacion': 4195.0,
#   'riesgo': 'ALTO'},
#  'El Guacamayo': {'departamento': 'Santander',
#   'lat': '6.2452658',
#   'lon': '-73.4975606',
#   'poblacion': 2005.0,
#   'riesgo': 'MEDIO'},
#  'El Guamo': {'departamento': 'Bolívar',
#   'lat': '10.0312607',
#   'lon': '-74.9754413',
#   'poblacion': 32373.0,
#   'riesgo': 'MEDIO'},
#  'El Molino': {'departamento': 'La Guajira',
#   'lat': '10.6523076',
#   'lon': '-72.9215565',
#   'poblacion': 8728.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Paso': {'departamento': 'Cesar',
#   'lat': '9.6589481',
#   'lon': '-73.7504695',
#   'poblacion': 22832.0,
#   'riesgo': 'ALTO'},
#  'El Peñol': {'departamento': 'Nariño',
#   'lat': '1.52412415',
#   'lon': '-77.4245481577532',
#   'poblacion': 6500.0,
#   'riesgo': 'ALTO'},
#  'El Peñón': {'departamento': 'Santander',
#   'lat': '6.08553175',
#   'lon': '-73.9336485499433',
#   'poblacion': 5140.0,
#   'riesgo': 'MEDIO'},
#  'El Piñon': {'departamento': 'Magdalena',
#   'lat': '10.4042864',
#   'lon': '-74.8243075',
#   'poblacion': 16752.0,
#   'riesgo': 'MEDIO'},
#  'El Playón': {'departamento': 'Santander',
#   'lat': '7.470891',
#   'lon': '-73.2033093',
#   'poblacion': 11776.0,
#   'riesgo': 'ALTO'},
#  'El Retén': {'departamento': 'Magdalena',
#   'lat': '10.612076',
#   'lon': '-74.2695268',
#   'poblacion': 22975.0,
#   'riesgo': 'ALTO'},
#  'El Roble': {'departamento': 'Sucre',
#   'lat': '9.1037704',
#   'lon': '-75.1952621',
#   'poblacion': 10550.0,
#   'riesgo': 'MEDIO'},
#  'El Rosal': {'departamento': 'Cundinamarca',
#   'lat': '4.8837938',
#   'lon': '-74.2344962131361',
#   'poblacion': 17254.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Rosario': {'departamento': 'Nariño',
#   'lat': '1.7432036',
#   'lon': '-77.3350718',
#   'poblacion': 10201.0,
#   'riesgo': 'ALTO'},
#  'El Santuario': {'departamento': 'Antioquia',
#   'lat': '6.1232786',
#   'lon': '-75.2651735797388',
#   'poblacion': 27120.0,
#   'riesgo': 'SIN RIESGO'},
#  'El Tablón De Gómez': {'departamento': 'Nariño',
#   'lat': '1.4272902',
#   'lon': '-77.0972848',
#   'poblacion': 12757.0,
#   'riesgo': 'ALTO'},
#  'El Tambo': {'departamento': 'Nariño',
#   'lat': '1.4081573',
#   'lon': '-77.3918509',
#   'poblacion': 12271.0,
#   'riesgo': 'ALTO'},
#  'El Tarra': {'departamento': 'Norte de Santander',
#   'lat': '8.6474367',
#   'lon': '-73.0336777',
#   'poblacion': 10957.0,
#   'riesgo': 'MEDIO'},
#  'El Zulia': {'departamento': 'Norte de Santander',
#   'lat': '7.9312397',
#   'lon': '-72.6011047',
#   'poblacion': 22843.0,
#   'riesgo': 'MEDIO'},
#  'El Águila': {'departamento': 'Valle del Cauca',
#   'lat': '4.9078333',
#   'lon': '-76.0421601',
#   'poblacion': 11069.0,
#   'riesgo': 'ALTO'},
#  'Elías': {'departamento': 'Huila',
#   'lat': '2.0136193',
#   'lon': '-75.9392336',
#   'poblacion': 3930.0,
#   'riesgo': 'ALTO'},
#  'Encino': {'departamento': 'Santander',
#   'lat': '6.1377564',
#   'lon': '-73.0990188',
#   'poblacion': 2497.0,
#   'riesgo': 'MEDIO'},
#  'Enciso': {'departamento': 'Santander',
#   'lat': '6.6498446',
#   'lon': '-72.6817354814915',
#   'poblacion': 3323.0,
#   'riesgo': 'MEDIO'},
#  'Entrerrios': {'departamento': 'Antioquia',
#   'lat': '6.59290725',
#   'lon': '-75.5633203898051',
#   'poblacion': 9950.0,
#   'riesgo': 'BAJO'},
#  'Envigado': {'departamento': 'Antioquia',
#   'lat': '6.1701345',
#   'lon': '-75.5874132',
#   'poblacion': 222410.0,
#   'riesgo': 'SIN RIESGO'},
#  'Facatativá': {'departamento': 'Cundinamarca',
#   'lat': '4.8097329',
#   'lon': '-74.3541284',
#   'poblacion': 132106.0,
#   'riesgo': 'SIN RIESGO'},
#  'Falan': {'departamento': 'Tolima',
#   'lat': '5.08818555',
#   'lon': '-74.9397798139435',
#   'poblacion': 9218.0,
#   'riesgo': 'BAJO'},
#  'Filadelfia': {'departamento': 'Caldas',
#   'lat': '5.2905202',
#   'lon': '-75.5873620028141',
#   'poblacion': 11034.0,
#   'riesgo': 'ALTO'},
#  'Filandia': {'departamento': 'Quindio',
#   'lat': '4.6910514',
#   'lon': '-75.6495398',
#   'poblacion': 13414.0,
#   'riesgo': 'SIN RIESGO'},
#  'Firavitoba': {'departamento': 'Boyacá',
#   'lat': '5.6690732',
#   'lon': '-72.9937461',
#   'poblacion': 5907.0,
#   'riesgo': 'BAJO'},
#  'Florencia': {'departamento': 'Cauca',
#   'lat': '1.6830289',
#   'lon': '-77.0726877',
#   'poblacion': 6132.0,
#   'riesgo': 'BAJO'},
#  'Floresta': {'departamento': 'Boyacá',
#   'lat': '5.8598286',
#   'lon': '-72.9188214',
#   'poblacion': 8108.0,
#   'riesgo': 'BAJO'},
#  'Florida': {'departamento': 'Valle del Cauca',
#   'lat': '3.3256006',
#   'lon': '-76.2370118',
#   'poblacion': 58122.0,
#   'riesgo': 'MEDIO'},
#  'Floridablanca': {'departamento': 'Santander',
#   'lat': '7.0625358',
#   'lon': '-73.0858228',
#   'poblacion': 265452.0,
#   'riesgo': 'SIN RIESGO'},
#  'Florián': {'departamento': 'Santander',
#   'lat': '5.7869132',
#   'lon': '-73.9702357040568',
#   'poblacion': 6301.0,
#   'riesgo': 'ALTO'},
#  'Fomeque': {'departamento': 'Cundinamarca',
#   'lat': '4.4871667',
#   'lon': '-73.8933937',
#   'poblacion': 12214.0,
#   'riesgo': 'MEDIO'},
#  'Fonseca': {'departamento': 'La Guajira',
#   'lat': '10.84200945',
#   'lon': '-72.7820258353363',
#   'poblacion': 33254.0,
#   'riesgo': 'ALTO'},
#  'Fortul': {'departamento': 'Arauca',
#   'lat': '6.7928124',
#   'lon': '-71.7743809',
#   'poblacion': 25379.0,
#   'riesgo': 'SIN RIESGO'},
#  'Fosca': {'departamento': 'Cundinamarca',
#   'lat': '4.31723725',
#   'lon': '-73.952438729045',
#   'poblacion': 7524.0,
#   'riesgo': 'BAJO'},
#  'Francisco Pizarro': {'departamento': 'Nariño',
#   'lat': '2.0419186',
#   'lon': '-78.6441196',
#   'poblacion': 15039.0,
#   'riesgo': 'ALTO'},
#  'Fredonia': {'departamento': 'Antioquia',
#   'lat': '5.87507465',
#   'lon': '-75.6908071247597',
#   'poblacion': 21561.0,
#   'riesgo': 'SIN RIESGO'},
#  'Fresno': {'departamento': 'Tolima',
#   'lat': '5.1535058',
#   'lon': '-75.0371423',
#   'poblacion': 30284.0,
#   'riesgo': 'BAJO'},
#  'Frontino': {'departamento': 'Antioquia',
#   'lat': '6.6762904',
#   'lon': '-76.3772009486133',
#   'poblacion': 16615.0,
#   'riesgo': 'SIN RIESGO'},
#  'Fuente De Oro': {'departamento': 'Meta',
#   'lat': '3.4600781',
#   'lon': '-73.618952',
#   'poblacion': 13263.0,
#   'riesgo': 'ALTO'},
#  'Fundación': {'departamento': 'Magdalena',
#   'lat': '10.4593846',
#   'lon': '-73.8407632291165',
#   'poblacion': 57344.0,
#   'riesgo': 'MEDIO'},
#  'Funes': {'departamento': 'Nariño',
#   'lat': '1.0004497',
#   'lon': '-77.4481684',
#   'poblacion': 29106.0,
#   'riesgo': 'ALTO'},
#  'Funza': {'departamento': 'Cundinamarca',
#   'lat': '4.7163036',
#   'lon': '-74.2122206',
#   'poblacion': 75350.0,
#   'riesgo': 'SIN RIESGO'},
#  'Fusagasugá': {'departamento': 'Cundinamarca',
#   'lat': '4.3369235',
#   'lon': '-74.3644854',
#   'poblacion': 134523.0,
#   'riesgo': 'SIN RIESGO'},
#  'Fúquene': {'departamento': 'Cundinamarca',
#   'lat': '5.4083822',
#   'lon': '-73.7733941432152',
#   'poblacion': 5617.0,
#   'riesgo': 'SIN RIESGO'},
#  'Gachala': {'departamento': 'Cundinamarca',
#   'lat': '4.66355795',
#   'lon': '-73.4917355847383',
#   'poblacion': 5715.0,
#   'riesgo': 'SIN RIESGO'},
#  'Gachancipá': {'departamento': 'Cundinamarca',
#   'lat': '4.9920291',
#   'lon': '-73.8721107',
#   'poblacion': 14442.0,
#   'riesgo': 'SIN RIESGO'},
#  'Gachantivá': {'departamento': 'Boyacá',
#   'lat': '5.7422941',
#   'lon': '-73.5360398524166',
#   'poblacion': 2654.0,
#   'riesgo': 'ALTO'},
#  'Gachetá': {'departamento': 'Cundinamarca',
#   'lat': '4.8174862',
#   'lon': '-73.6371013',
#   'poblacion': 11086.0,
#   'riesgo': 'BAJO'},
#  'Galapa': {'departamento': 'Atlántico',
#   'lat': '10.8982834',
#   'lon': '-74.8795440928407',
#   'poblacion': 42706.0,
#   'riesgo': 'SIN RIESGO'},
#  'Galeras': {'departamento': 'Sucre',
#   'lat': '9.1606864',
#   'lon': '-75.0487747',
#   'poblacion': 20188.0,
#   'riesgo': 'ALTO'},
#  'Galán': {'departamento': 'Santander',
#   'lat': '6.67423275',
#   'lon': '-73.3211114215782',
#   'poblacion': 2311.0,
#   'riesgo': 'BAJO'},
#  'Gama': {'departamento': 'Cundinamarca',
#   'lat': '4.7636089',
#   'lon': '-73.6100336',
#   'poblacion': 3996.0,
#   'riesgo': 'SIN RIESGO'},
#  'Gamarra': {'departamento': 'Cesar',
#   'lat': '8.32013985',
#   'lon': '-73.7147850264338',
#   'poblacion': 16644.0,
#   'riesgo': 'MEDIO'},
#  'Gambita': {'departamento': 'Santander',
#   'lat': '5.91628015',
#   'lon': '-73.3158972254147',
#   'poblacion': 5044.0,
#   'riesgo': 'MEDIO'},
#  'Gameza': {'departamento': 'Boyacá',
#   'lat': '5.803284',
#   'lon': '-72.8042373',
#   'poblacion': 4856.0,
#   'riesgo': 'MEDIO'},
#  'Garagoa': {'departamento': 'Boyacá',
#   'lat': '5.08754645',
#   'lon': '-73.3160243820969',
#   'poblacion': 16944.0,
#   'riesgo': 'MEDIO'},
#  'Garzón': {'departamento': 'Huila',
#   'lat': '2.1625835',
#   'lon': '-75.5551444935525',
#   'poblacion': 88213.0,
#   'riesgo': 'ALTO'},
#  'Gigante': {'departamento': 'Huila',
#   'lat': '2.3881745',
#   'lon': '-75.5468663',
#   'poblacion': 33313.0,
#   'riesgo': 'ALTO'},
#  'Ginebra': {'departamento': 'Valle del Cauca',
#   'lat': '3.7489066',
#   'lon': '-76.2002974662379',
#   'poblacion': 21055.0,
#   'riesgo': 'ALTO'},
#  'Giraldo': {'departamento': 'Antioquia',
#   'lat': '6.6804539',
#   'lon': '-75.95338',
#   'poblacion': 4029.0,
#   'riesgo': 'SIN RIESGO'},
#  'Girardot': {'departamento': 'Cundinamarca',
#   'lat': '4.306643',
#   'lon': '-74.8015665',
#   'poblacion': 105085.0,
#   'riesgo': 'SIN RIESGO'},
#  'Girardota': {'departamento': 'Antioquia',
#   'lat': '6.3757634',
#   'lon': '-75.4405371052123',
#   'poblacion': 54219.0,
#   'riesgo': 'SIN RIESGO'},
#  'Girón': {'departamento': 'Santander',
#   'lat': '7.04975065',
#   'lon': '-73.2906385846527',
#   'poblacion': 180305.0,
#   'riesgo': 'SIN RIESGO'},
#  'González': {'departamento': 'Cesar',
#   'lat': '8.39523625',
#   'lon': '-73.3736979660456',
#   'poblacion': 6990.0,
#   'riesgo': 'ALTO'},
#  'Gramalote': {'departamento': 'Norte de Santander',
#   'lat': '7.8334255',
#   'lon': '-72.4773583',
#   'poblacion': 5567.0,
#   'riesgo': 'MEDIO'},
#  'Granada': {'departamento': 'Meta',
#   'lat': '3.548259',
#   'lon': '-73.7051174',
#   'poblacion': 62209.0,
#   'riesgo': 'ALTO'},
#  'Guaca': {'departamento': 'Santander',
#   'lat': '6.9351737',
#   'lon': '-72.8058804042012',
#   'poblacion': 6395.0,
#   'riesgo': 'BAJO'},
#  'Guacamayas': {'departamento': 'Boyacá',
#   'lat': '6.44327705',
#   'lon': '-72.5162539682056',
#   'poblacion': 1693.0,
#   'riesgo': 'BAJO'},
#  'Guacarí': {'departamento': 'Valle del Cauca',
#   'lat': '3.7775365',
#   'lon': '-76.3018185920617',
#   'poblacion': 34522.0,
#   'riesgo': 'MEDIO'},
#  'Guachetá': {'departamento': 'Cundinamarca',
#   'lat': '5.3850905',
#   'lon': '-73.6859041',
#   'poblacion': 11385.0,
#   'riesgo': 'SIN RIESGO'},
#  'Guachucal': {'departamento': 'Nariño',
#   'lat': '0.9573434',
#   'lon': '-77.7333581',
#   'poblacion': 15652.0,
#   'riesgo': 'ALTO'},
#  'Guadalajara De Buga': {'departamento': 'Valle del Cauca',
#   'lat': '3.9000578',
#   'lon': '-76.302013',
#   'poblacion': 115249.0,
#   'riesgo': 'MEDIO'},
#  'Guadalupe': {'departamento': 'Santander',
#   'lat': '6.23740655',
#   'lon': '-73.3953837075083',
#   'poblacion': 4756.0,
#   'riesgo': 'BAJO'},
#  'Guaduas': {'departamento': 'Cundinamarca',
#   'lat': '5.20444635',
#   'lon': '-74.6662023992902',
#   'poblacion': 38366.0,
#   'riesgo': 'SIN RIESGO'},
#  'Guaitarilla': {'departamento': 'Nariño',
#   'lat': '1.1305245',
#   'lon': '-77.5483421',
#   'poblacion': 12011.0,
#   'riesgo': 'ALTO'},
#  'Gualmatán': {'departamento': 'Nariño',
#   'lat': '0.919293',
#   'lon': '-77.5685523',
#   'poblacion': 5767.0,
#   'riesgo': 'ALTO'},
#  'Guamal': {'departamento': 'Meta',
#   'lat': '3.7943196',
#   'lon': '-73.5522759',
#   'poblacion': 9366.0,
#   'riesgo': 'MEDIO'},
#  'Guapotá': {'departamento': 'Santander',
#   'lat': '6.32074375',
#   'lon': '-73.3174942370605',
#   'poblacion': 2139.0,
#   'riesgo': 'SIN RIESGO'},
#  'Guaranda': {'departamento': 'Sucre',
#   'lat': '8.39295295',
#   'lon': '-74.8001174510006',
#   'poblacion': 17422.0,
#   'riesgo': 'ALTO'},
#  'Guarne': {'departamento': 'Antioquia',
#   'lat': '6.272654',
#   'lon': '-75.4392567939736',
#   'poblacion': 47797.0,
#   'riesgo': 'SIN RIESGO'},
#  'Guasca': {'departamento': 'Cundinamarca',
#   'lat': '4.8665366',
#   'lon': '-73.877972',
#   'poblacion': 14759.0,
#   'riesgo': 'SIN RIESGO'},
#  'Guatape': {'departamento': 'Antioquia',
#   'lat': '6.2525941',
#   'lon': '-75.1668834631162',
#   'poblacion': 29722.0,
#   'riesgo': 'BAJO'},
#  'Guataquí': {'departamento': 'Cundinamarca',
#   'lat': '4.5181995',
#   'lon': '-74.7899996',
#   'poblacion': 8576.0,
#   'riesgo': 'MEDIO'},
#  'Guatavita': {'departamento': 'Cundinamarca',
#   'lat': '4.935694',
#   'lon': '-73.8322377',
#   'poblacion': 6898.0,
#   'riesgo': 'MEDIO'},
#  'Guateque': {'departamento': 'Boyacá',
#   'lat': '5.0226102',
#   'lon': '-73.4919901707052',
#   'poblacion': 9603.0,
#   'riesgo': 'MEDIO'},
#  'Guavatá': {'departamento': 'Santander',
#   'lat': '5.94801435',
#   'lon': '-73.7153208406455',
#   'poblacion': 3679.0,
#   'riesgo': 'BAJO'},
#  'Guayabal De Siquima': {'departamento': 'Cundinamarca',
#   'lat': '4.8782654',
#   'lon': '-74.4675635',
#   'poblacion': 3638.0,
# ...
#   'lat': '5.1960563',
#   'lon': '-73.8867488',
#   'poblacion': 8801.0,
#   'riesgo': 'BAJO'},
#  'Tello': {'departamento': 'Huila',
#   'lat': '3.02109705',
#   'lon': '-75.0705706707433',
#   'poblacion': 9740.0,
#   'riesgo': 'ALTO'},
#  'Tena': {'departamento': 'Cundinamarca',
#   'lat': '4.6554712',
#   'lon': '-74.3893393',
#   'poblacion': 8941.0,
#   'riesgo': 'BAJO'},
#  'Tenerife': {'departamento': 'Magdalena',
#   'lat': '9.9003487',
#   'lon': '-74.8589973',
#   'poblacion': 12243.0,
#   'riesgo': 'ALTO'},
#  'Tenjo': {'departamento': 'Cundinamarca',
#   'lat': '4.82671705',
#   'lon': '-74.1535700740977',
#   'poblacion': 19849.0,
#   'riesgo': 'SIN RIESGO'},
#  'Tenza': {'departamento': 'Boyacá',
#   'lat': '5.07638215',
#   'lon': '-73.4173608618348',
#   'poblacion': 4112.0,
#   'riesgo': 'ALTO'},
#  'Teorama': {'departamento': 'Norte de Santander',
#   'lat': '8.5432291',
#   'lon': '-73.1876191',
#   'poblacion': 21524.0,
#   'riesgo': 'ALTO'},
#  'Teruel': {'departamento': 'Huila',
#   'lat': '2.7416333',
#   'lon': '-75.5683448',
#   'poblacion': 8749.0,
#   'riesgo': 'ALTO'},
#  'Tesalia': {'departamento': 'Huila',
#   'lat': '2.54659965',
#   'lon': '-75.7085071585615',
#   'poblacion': 9248.0,
#   'riesgo': 'MEDIO'},
#  'Tibacuy': {'departamento': 'Cundinamarca',
#   'lat': '4.32425315',
#   'lon': '-74.4794379792184',
#   'poblacion': 4828.0,
#   'riesgo': 'SIN RIESGO'},
#  'Tibaná': {'departamento': 'Boyacá',
#   'lat': '5.31086645',
#   'lon': '-73.3911830386457',
#   'poblacion': 9186.0,
#   'riesgo': 'MEDIO'},
#  'Tibasosa': {'departamento': 'Boyacá',
#   'lat': '5.74808125',
#   'lon': '-73.0127908193562',
#   'poblacion': 14063.0,
#   'riesgo': 'MEDIO'},
#  'Tibirita': {'departamento': 'Cundinamarca',
#   'lat': '5.0533345',
#   'lon': '-73.5036644',
#   'poblacion': 2950.0,
#   'riesgo': 'MEDIO'},
#  'Tibú': {'departamento': 'Norte de Santander',
#   'lat': '8.7828443',
#   'lon': '-72.8988647',
#   'poblacion': 36502.0,
#   'riesgo': 'BAJO'},
#  'Tierralta': {'departamento': 'Córdoba',
#   'lat': '7.84705275',
#   'lon': '-76.2248678226981',
#   'poblacion': 99911.0,
#   'riesgo': 'BAJO'},
#  'Timaná': {'departamento': 'Huila',
#   'lat': '1.95016885',
#   'lon': '-75.9265797375061',
#   'poblacion': 20315.0,
#   'riesgo': 'ALTO'},
#  'Timbiquí': {'departamento': 'Cauca',
#   'lat': '2.659671',
#   'lon': '-77.4270696387881',
#   'poblacion': 21617.0,
#   'riesgo': 'INVIABLE SANITARIAMENTE'},
#  'Timbío': {'departamento': 'Cauca',
#   'lat': '2.38094855',
#   'lon': '-76.7008765859766',
#   'poblacion': 33883.0,
#   'riesgo': 'SIN RIESGO'},
#  'Tinjacá': {'departamento': 'Boyacá',
#   'lat': '5.572943',
#   'lon': '-73.6709217819118',
#   'poblacion': 3035.0,
#   'riesgo': 'MEDIO'},
#  'Tipacoque': {'departamento': 'Boyacá',
#   'lat': '6.4279842',
#   'lon': '-72.7001077785735',
#   'poblacion': 3206.0,
#   'riesgo': 'MEDIO'},
#  'Tiquisio': {'departamento': 'Bolívar',
#   'lat': '8.48191435',
#   'lon': '-74.2836410621054',
#   'poblacion': 22041.0,
#   'riesgo': 'ALTO'},
#  'Titiribí': {'departamento': 'Antioquia',
#   'lat': '6.06557735',
#   'lon': '-75.8029460165566',
#   'poblacion': 14393.0,
#   'riesgo': 'BAJO'},
#  'Toca': {'departamento': 'Boyacá',
#   'lat': '5.5771231',
#   'lon': '-73.1684500204949',
#   'poblacion': 10157.0,
#   'riesgo': 'ALTO'},
#  'Tocaima': {'departamento': 'Cundinamarca',
#   'lat': '4.4884172',
#   'lon': '-74.6546146778065',
#   'poblacion': 18387.0,
#   'riesgo': 'SIN RIESGO'},
#  'Tocancipá': {'departamento': 'Cundinamarca',
#   'lat': '4.9720528',
#   'lon': '-73.9217851651149',
#   'poblacion': 31975.0,
#   'riesgo': 'SIN RIESGO'},
#  'Togüí': {'departamento': 'Boyacá',
#   'lat': '5.9170442',
#   'lon': '-73.4964349053907',
#   'poblacion': 4966.0,
#   'riesgo': 'ALTO'},
#  'Toledo': {'departamento': 'Norte de Santander',
#   'lat': '7.3085866',
#   'lon': '-72.4834315',
#   'poblacion': 17283.0,
#   'riesgo': 'MEDIO'},
#  'Tolú Viejo': {'departamento': 'Sucre',
#   'lat': '9.45082',
#   'lon': '-75.43864',
#   'poblacion': 18897.0,
#   'riesgo': 'ALTO'},
#  'Tona': {'departamento': 'Santander',
#   'lat': '7.15363455',
#   'lon': '-72.9602124126953',
#   'poblacion': 7085.0,
#   'riesgo': 'MEDIO'},
#  'Topaipí': {'departamento': 'Cundinamarca',
#   'lat': '5.3353896',
#   'lon': '-74.3026812',
#   'poblacion': 4529.0,
#   'riesgo': 'BAJO'},
#  'Toribio': {'departamento': 'Cauca',
#   'lat': '2.9554697',
#   'lon': '-76.2686889',
#   'poblacion': 29187.0,
#   'riesgo': 'BAJO'},
#  'Toro': {'departamento': 'Valle del Cauca',
#   'lat': '4.6094813',
#   'lon': '-76.0780048',
#   'poblacion': 16394.0,
#   'riesgo': 'MEDIO'},
#  'Tota': {'departamento': 'Boyacá',
#   'lat': '5.4766073',
#   'lon': '-73.01337605029',
#   'poblacion': 5386.0,
#   'riesgo': 'ALTO'},
#  'Totoró': {'departamento': 'Cauca',
#   'lat': '2.49664855',
#   'lon': '-76.3573801541137',
#   'poblacion': 20123.0,
#   'riesgo': 'ALTO'},
#  'Trinidad': {'departamento': 'Casanare',
#   'lat': '5.407867',
#   'lon': '-71.6617007',
#   'poblacion': 14741.0,
#   'riesgo': 'MEDIO'},
#  'Trujillo': {'departamento': 'Valle del Cauca',
#   'lat': '4.2122451',
#   'lon': '-76.3186782',
#   'poblacion': 18100.0,
#   'riesgo': 'MEDIO'},
#  'Tubará': {'departamento': 'Atlántico',
#   'lat': '10.8993966',
#   'lon': '-74.986310136312',
#   'poblacion': 11027.0,
#   'riesgo': 'BAJO'},
#  'Tuluá': {'departamento': 'Valle del Cauca',
#   'lat': '4.0856667',
#   'lon': '-76.1972779',
#   'poblacion': 211581.0,
#   'riesgo': 'MEDIO'},
#  'Tunja': {'departamento': 'Boyacá',
#   'lat': '5.5158168',
#   'lon': '-73.3777319537211',
#   'poblacion': 188340.0,
#   'riesgo': 'BAJO'},
#  'Tununguá': {'departamento': 'Boyacá',
#   'lat': '5.71736945',
#   'lon': '-73.9312694917641',
#   'poblacion': 1840.0,
#   'riesgo': 'ALTO'},
#  'Turbaco': {'departamento': 'Bolívar',
#   'lat': '10.3305871',
#   'lon': '-75.4127345',
#   'poblacion': 72168.0,
#   'riesgo': 'MEDIO'},
#  'Turbaná': {'departamento': 'Bolívar',
#   'lat': '10.233116',
#   'lon': '-75.448718562246',
#   'poblacion': 14883.0,
#   'riesgo': 'ALTO'},
#  'Turbo': {'departamento': 'Antioquia',
#   'lat': '8.0950848',
#   'lon': '-76.728545',
#   'poblacion': 159268.0,
#   'riesgo': 'SIN RIESGO'},
#  'Turmequé': {'departamento': 'Boyacá',
#   'lat': '5.30145575',
#   'lon': '-73.5115862563329',
#   'poblacion': 6182.0,
#   'riesgo': 'ALTO'},
#  'Tuta': {'departamento': 'Boyacá',
#   'lat': '5.67861455',
#   'lon': '-73.187056315004',
#   'poblacion': 9673.0,
#   'riesgo': 'BAJO'},
#  'Tutazá': {'departamento': 'Boyacá',
#   'lat': '6.0739913',
#   'lon': '-72.8624193418934',
#   'poblacion': 1890.0,
#   'riesgo': 'SIN RIESGO'},
#  'Támara': {'departamento': 'Casanare',
#   'lat': '5.8304221',
#   'lon': '-72.1630205',
#   'poblacion': 7040.0,
#   'riesgo': 'ALTO'},
#  'Támesis': {'departamento': 'Antioquia',
#   'lat': '5.67502205',
#   'lon': '-75.7322397506356',
#   'poblacion': 14732.0,
#   'riesgo': 'SIN RIESGO'},
#  'Tópaga': {'departamento': 'Boyacá',
#   'lat': '5.76645735',
#   'lon': '-72.8403633596765',
#   'poblacion': 3694.0,
#   'riesgo': 'MEDIO'},
#  'Túquerres': {'departamento': 'Nariño',
#   'lat': '1.0877864',
#   'lon': '-77.6190579',
#   'poblacion': 40599.0,
#   'riesgo': 'ALTO'},
#  'Ubalá': {'departamento': 'Cundinamarca',
#   'lat': '4.7444552',
#   'lon': '-73.534592',
#   'poblacion': 10718.0,
#   'riesgo': 'BAJO'},
#  'Ubaque': {'departamento': 'Cundinamarca',
#   'lat': '4.4822948',
#   'lon': '-73.9349377',
#   'poblacion': 6166.0,
#   'riesgo': 'MEDIO'},
#  'Ulloa': {'departamento': 'Valle del Cauca',
#   'lat': '4.7036572',
#   'lon': '-75.7379416',
#   'poblacion': 5457.0,
#   'riesgo': 'MEDIO'},
#  'Umbita': {'departamento': 'Boyacá',
#   'lat': '5.22539545',
#   'lon': '-73.4580645581542',
#   'poblacion': 10314.0,
#   'riesgo': 'ALTO'},
#  'Une': {'departamento': 'Cundinamarca',
#   'lat': '4.30628325',
#   'lon': '-74.0622059634192',
#   'poblacion': 9196.0,
#   'riesgo': 'SIN RIESGO'},
#  'Uramita': {'departamento': 'Antioquia',
#   'lat': '6.91332525',
#   'lon': '-76.1364912088278',
#   'poblacion': 8238.0,
#   'riesgo': 'BAJO'},
#  'Uribe': {'departamento': 'Meta',
#   'lat': '3.2413296',
#   'lon': '-74.3510657',
#   'poblacion': 16155.0,
#   'riesgo': 'MEDIO'},
#  'Uribia': {'departamento': 'La Guajira',
#   'lat': '11.99171685',
#   'lon': '-71.6768607116711',
#   'poblacion': 174287.0,
#   'riesgo': 'BAJO'},
#  'Urrao': {'departamento': 'Antioquia',
#   'lat': '6.29563115',
#   'lon': '-76.263332652202',
#   'poblacion': 44648.0,
#   'riesgo': 'SIN RIESGO'},
#  'Urumita': {'departamento': 'La Guajira',
#   'lat': '10.49582235',
#   'lon': '-72.9359535592545',
#   'poblacion': 17910.0,
#   'riesgo': 'MEDIO'},
#  'Usiacurí': {'departamento': 'Atlántico',
#   'lat': '10.7386503',
#   'lon': '-74.9804049641444',
#   'poblacion': 9392.0,
#   'riesgo': 'SIN RIESGO'},
#  'Valdivia': {'departamento': 'Antioquia',
#   'lat': '7.2423401',
#   'lon': '-75.3696194253646',
#   'poblacion': 22179.0,
#   'riesgo': 'SIN RIESGO'},
#  'Valencia': {'departamento': 'Córdoba',
#   'lat': '8.2572483',
#   'lon': '-76.1499084',
#   'poblacion': 42971.0,
#   'riesgo': 'BAJO'},
#  'Valle De San José': {'departamento': 'Santander',
#   'lat': '6.4346425',
#   'lon': '-73.1128692952179',
#   'poblacion': 6355.0,
#   'riesgo': 'MEDIO'},
#  'Valle Del Guamuez': {'departamento': 'Putumayo',
#   'lat': '0.44932225',
#   'lon': '-76.8784508864243',
#   'poblacion': 51842.0,
#   'riesgo': 'ALTO'},
#  'Valledupar': {'departamento': 'Cesar',
#   'lat': '10.34311145',
#   'lon': '-73.3757933882845',
#   'poblacion': 453205.0,
#   'riesgo': 'SIN RIESGO'},
#  'Valparaíso': {'departamento': 'Caquetá',
#   'lat': '1.1961248',
#   'lon': '-75.7059684',
#   'poblacion': 11629.0,
#   'riesgo': 'BAJO'},
#  'Vegachí': {'departamento': 'Antioquia',
#   'lat': '6.86039955',
#   'lon': '-74.7235243423101',
#   'poblacion': 9448.0,
#   'riesgo': 'SIN RIESGO'},
#  'Venecia': {'departamento': 'Cundinamarca',
#   'lat': '4.0889462',
#   'lon': '-74.4784456',
#   'poblacion': 4060.0,
#   'riesgo': 'BAJO'},
#  'Ventaquemada': {'departamento': 'Boyacá',
#   'lat': '5.384167',
#   'lon': '-73.524319392617',
#   'poblacion': 15442.0,
#   'riesgo': 'MEDIO'},
#  'Vergara': {'departamento': 'Cundinamarca',
#   'lat': '5.1183756',
#   'lon': '-74.3451863',
#   'poblacion': 7677.0,
#   'riesgo': 'BAJO'},
#  'Versalles': {'departamento': 'Valle del Cauca',
#   'lat': '4.61728755',
#   'lon': '-76.2319256505117',
#   'poblacion': 7214.0,
#   'riesgo': 'ALTO'},
#  'Vetas': {'departamento': 'Santander',
#   'lat': '7.32082525',
#   'lon': '-72.8858798035649',
#   'poblacion': 2435.0,
#   'riesgo': 'ALTO'},
#  'Vianí': {'departamento': 'Cundinamarca',
#   'lat': '4.87943995',
#   'lon': '-74.5644987170771',
#   'poblacion': 4191.0,
#   'riesgo': 'BAJO'},
#  'Victoria': {'departamento': 'Caldas',
#   'lat': '4.852512',
#   'lon': '-75.4073776',
#   'poblacion': 8415.0,
#   'riesgo': 'ALTO'},
#  'Vijes': {'departamento': 'Valle del Cauca',
#   'lat': '3.75606075',
#   'lon': '-76.4885301459711',
#   'poblacion': 11010.0,
#   'riesgo': 'ALTO'},
#  'Villa Caro': {'departamento': 'Norte de Santander',
#   'lat': '7.9144121',
#   'lon': '-72.972949',
#   'poblacion': 5192.0,
#   'riesgo': 'MEDIO'},
#  'Villa De Leyva': {'departamento': 'Boyacá',
#   'lat': '5.6336805',
#   'lon': '-73.523548',
#   'poblacion': 16478.0,
#   'riesgo': 'MEDIO'},
#  'Villa De San Diego De Ubate': {'departamento': 'Cundinamarca',
#   'lat': '5.314307',
#   'lon': '-73.816287',
#   'poblacion': 38809.0,
#   'riesgo': 'SIN RIESGO'},
#  'Villa Del Rosario': {'departamento': 'Norte de Santander',
#   'lat': '7.8318933',
#   'lon': '-72.4717181',
#   'poblacion': 88433.0,
#   'riesgo': 'BAJO'},
#  'Villa Rica': {'departamento': 'Cauca',
#   'lat': '3.1818326',
#   'lon': '-76.4602123912337',
#   'poblacion': 16189.0,
#   'riesgo': 'MEDIO'},
#  'Villagarzón': {'departamento': 'Putumayo',
#   'lat': '0.9227343',
#   'lon': '-76.7800669458213',
#   'poblacion': 21134.0,
#   'riesgo': 'ALTO'},
#  'Villagómez': {'departamento': 'Cundinamarca',
#   'lat': '5.2731679',
#   'lon': '-74.1951778',
#   'poblacion': 2171.0,
#   'riesgo': 'SIN RIESGO'},
#  'Villamaría': {'departamento': 'Caldas',
#   'lat': '4.92729255',
#   'lon': '-75.4534734191051',
#   'poblacion': 56288.0,
#   'riesgo': 'ALTO'},
#  'Villanueva': {'departamento': 'Santander',
#   'lat': '6.6712394',
#   'lon': '-73.1753984',
#   'poblacion': 23859.0,
#   'riesgo': 'SIN RIESGO'},
#  'Villapinzón': {'departamento': 'Cundinamarca',
#   'lat': '5.2443517',
#   'lon': '-73.5930211495679',
#   'poblacion': 19742.0,
#   'riesgo': 'SIN RIESGO'},
#  'Villarrica': {'departamento': 'Tolima',
#   'lat': '3.9606919',
#   'lon': '-74.6080054',
#   'poblacion': 5449.0,
#   'riesgo': 'INVIABLE SANITARIAMENTE'},
#  'Villavicencio': {'departamento': 'Meta',
#   'lat': '4.1315113',
#   'lon': '-73.6206667',
#   'poblacion': 484429.0,
#   'riesgo': 'MEDIO'},
#  'Villavieja': {'departamento': 'Huila',
#   'lat': '3.28398155',
#   'lon': '-75.1212482524092',
#   'poblacion': 7314.0,
#   'riesgo': 'MEDIO'},
#  'Villeta': {'departamento': 'Cundinamarca',
#   'lat': '5.00754475',
#   'lon': '-74.4849361701327',
#   'poblacion': 25164.0,
#   'riesgo': 'SIN RIESGO'},
#  'Viotá': {'departamento': 'Cundinamarca',
#   'lat': '4.43815535',
#   'lon': '-74.4987070546634',
#   'poblacion': 13351.0,
#   'riesgo': 'BAJO'},
#  'Viracachá': {'departamento': 'Boyacá',
#   'lat': '5.44749285',
#   'lon': '-73.2667174517992',
#   'poblacion': 3222.0,
#   'riesgo': 'MEDIO'},
#  'Vista Hermosa': {'departamento': 'Meta',
#   'lat': '3.12632435',
#   'lon': '-73.7518683691829',
#   'poblacion': 10696.0,
#   'riesgo': 'ALTO'},
#  'Viterbo': {'departamento': 'Caldas',
#   'lat': '5.0379416',
#   'lon': '-75.8860540141681',
#   'poblacion': 12469.0,
#   'riesgo': 'ALTO'},
#  'Vélez': {'departamento': 'Santander',
#   'lat': '6.0123632',
#   'lon': '-73.6729598',
#   'poblacion': 19057.0,
#   'riesgo': 'MEDIO'},
#  'Yacopí': {'departamento': 'Cundinamarca',
#   'lat': '5.61170265',
#   'lon': '-74.4132486919779',
#   'poblacion': 16951.0,
#   'riesgo': 'MEDIO'},
#  'Yacuanquer': {'departamento': 'Nariño',
#   'lat': '1.1158819',
#   'lon': '-77.4017561',
#   'poblacion': 10968.0,
#   'riesgo': 'ALTO'},
#  'Yaguará': {'departamento': 'Huila',
#   'lat': '2.63616895',
#   'lon': '-75.5199613469619',
#   'poblacion': 8952.0,
#   'riesgo': 'ALTO'},
#  'Yalí': {'departamento': 'Antioquia',
#   'lat': '6.7180046',
#   'lon': '-74.7527692275294',
#   'poblacion': 8318.0,
#   'riesgo': 'SIN RIESGO'},
#  'Yarumal': {'departamento': 'Antioquia',
#   'lat': '7.0072117',
#   'lon': '-75.4086393846519',
#   'poblacion': 46865.0,
#   'riesgo': 'BAJO'},
#  'Yolombó': {'departamento': 'Antioquia',
#   'lat': '6.6685477',
#   'lon': '-74.6304559875371',
#   'poblacion': 23958.0,
#   'riesgo': 'SIN RIESGO'},
#  'Yondó': {'departamento': 'Antioquia',
#   'lat': '7.0044426',
#   'lon': '-73.9113922',
#   'poblacion': 18613.0,
#   'riesgo': 'SIN RIESGO'},
#  'Yopal': {'departamento': 'Casanare',
#   'lat': '5.3356662',
#   'lon': '-72.3936931',
#   'poblacion': 139734.0,
#   'riesgo': 'BAJO'},
#  'Yotoco': {'departamento': 'Valle del Cauca',
#   'lat': '3.89766105',
#   'lon': '-76.387873049896',
#   'poblacion': 16263.0,
#   'riesgo': 'MEDIO'},
#  'Yumbo': {'departamento': 'Valle del Cauca',
#   'lat': '3.5842137',
#   'lon': '-76.4949945',
#   'poblacion': 117118.0,
#   'riesgo': 'MEDIO'},
#  'Zambrano': {'departamento': 'Bolívar',
#   'lat': '9.7414779',
#   'lon': '-74.8177731',
#   'poblacion': 11611.0,
#   'riesgo': 'ALTO'},
#  'Zapatoca': {'departamento': 'Santander',
#   'lat': '6.8510075',
#   'lon': '-73.2175583580674',
#   'poblacion': 8929.0,
#   'riesgo': 'SIN RIESGO'},
#  'Zapayán': {'departamento': 'Magdalena',
#   'lat': '10.1682143',
#   'lon': '-74.7159253',
#   'poblacion': 8801.0,
#   'riesgo': 'INVIABLE SANITARIAMENTE'},
#  'Zaragoza': {'departamento': 'Antioquia',
#   'lat': '7.4949425',
#   'lon': '-74.9307176113023',
#   'poblacion': 30738.0,
#   'riesgo': 'MEDIO'},
#  'Zarzal': {'departamento': 'Valle del Cauca',
#   'lat': '4.3669411',
#   'lon': '-76.0568885033836',
#   'poblacion': 45227.0,
#   'riesgo': 'SIN RIESGO'},
#  'Zetaquira': {'departamento': 'Boyacá',
#   'lat': '5.2821538',
#   'lon': '-73.1669653272936',
#   'poblacion': 4557.0,
#   'riesgo': 'ALTO'},
#  'Zipacón': {'departamento': 'Cundinamarca',
#   'lat': '4.75282155',
#   'lon': '-74.3790544895751',
#   'poblacion': 5570.0,
#   'riesgo': 'ALTO'},
#  'Zipaquirá': {'departamento': 'Cundinamarca',
#   'lat': '5.0620431',
#   'lon': '-74.062503007411',
#   'poblacion': 122347.0,
#   'riesgo': 'SIN RIESGO'},
#  'Zona Bananera': {'departamento': 'Magdalena',
#   'lat': '10.7969213',
#   'lon': '-74.1807783360044',
#   'poblacion': 60524.0,
#   'riesgo': 'ALTO'},
#  'Útica': {'departamento': 'Cundinamarca',
#   'lat': '5.19028395',
#   'lon': '-74.475574192475',
#   'poblacion': 41326.0,
#   'riesgo': 'SIN RIESGO'}}

# %%
# Write nodes.csv

with open('nodes.csv', 'w') as outf:
    outf.write('municipio,departamento,lat,lon,poblacion,riesgo\n')
    for n in nodes:
        if not math.isnan(nodes[n]['poblacion']):
          outf.write('%s,%s,%s,%s,%d,%s\n' % (n, nodes[n]['departamento'], nodes[n]['lat'], nodes[n]['lon'], nodes[n]['poblacion'], nodes[n]['riesgo']) )

# %%
import geopy.distance

def get_distance(coords_1, coords_2):
  return geopy.distance.vincenty(coords_1, coords_2).km
  

nd = pd.read_csv('nodes.csv')

# %%
# Max distance for creating an edge
edges = []
distance_limit = 100


for i in range(len(nd)): 
  c1 = (nd.loc[i,'lat'],nd.loc[i,'lon'])
  for j in range(i+1, len(nd)) : 
    c2 = (nd.loc[j,'lat'],nd.loc[j,'lon'])
    distance = get_distance(c1, c2)
    if distance < distance_limit:
      edges.append([nd.loc[i,'municipio'],nd.loc[j,'municipio'],distance])
      
len (edges)
# Out:
# 35231

# %%
# Write edges file
with open('edges.csv', 'w') as outf:
    outf.write('source,target,weight\n')
    for edge in edges:
        outf.write('%s,%s,%d\n' % (edge[0], edge[1], edge[2]))
